# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
# !pip install numpy scipy matplotlib
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result
# Out:
# Requirement already satisfied: numpy in /workspaces/afernandez-probability-distribution-exercises-project-with-python/.venv/lib/python3.11/site-packages (2.4.2)
# Requirement already satisfied: scipy in /workspaces/afernandez-probability-distribution-exercises-project-with-python/.venv/lib/python3.11/site-packages (1.17.1)
# Requirement already satisfied: matplotlib in /workspaces/afernandez-probability-distribution-exercises-project-with-python/.venv/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /workspaces/afernandez-probability-distribution-exercises-project-with-python/.venv/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /workspaces/afernandez-probability-distribution-exercises-project-with-python/.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspaces/afernandez-probability-distribution-exercises-project-with-python/.venv/lib/python3.11/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspaces/afernandez-probability-distribution-exercises-project-with-python/.venv/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /workspaces/afernandez-probability-distribution-exercises-project-with-python/.venv/lib/python3.11/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /workspaces/afernandez-probability-distribution-exercises-project-with-python/.venv/lib/python3.11/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /workspaces/afernandez-probability-distribution-exercises-project-with-python/.venv/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /workspaces/afernandez-probability-distribution-exercises-project-with-python/.venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /workspaces/afernandez-probability-distribution-exercises-project-with-python/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicios
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %% [markdown]
# Distribucion Normal

# %%
from scipy.stats import norm
import numpy as np

# %%
def dnorm(x, mean=0, std=1):
    return norm.pdf(x, loc=mean, scale=std)

def pnorm(x, mean=0, std=1):
    return norm.cdf(x, loc=mean, scale=std)

def qnorm(p, mean=0, std=1):
    return norm.ppf(p, loc=mean, scale=std)

def rnorm(n, mean=0, std=1):
    return norm.rvs(loc=mean, scale=std, size=n)

# %% [markdown]
# se crean funciones equivalentes a las de la distribución binomial pero para las distribuciones normal y uniforme

# %% [markdown]
# Prueba distribucion normal

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

mean = 0
std = 1

data = np.arange(-5, 5, 0.01)

pdf = dnorm(data, mean, std)
cdf = pnorm(data, mean, std)

plt.plot(data, pdf)
plt.title("Normal PDF")
plt.show()

# %% [markdown]
# en esta sección se genera una serie de valores para representar gráficamente el comportamiento

# %% [markdown]
# Distribucion Uniforme

# %%
from scipy.stats import uniform

def dunif(x, min=0, max=1):
    return uniform.pdf(x, loc=min, scale=max-min)

def punif(x, min=0, max=1):
    return uniform.cdf(x, loc=min, scale=max-min)

def qunif(p, min=0, max=1):
    return uniform.ppf(p, loc=min, scale=max-min)

def runif(n, min=0, max=1):
    return uniform.rvs(loc=min, scale=max-min, size=n)

# %% [markdown]
# Funciones equivalentes para la distribución uniforme, s parámetros mínimo y máximo del intervalo.

# %% [markdown]
# Prueba distribucion unifrome

# %%
np.random.seed(42)

min_val = 0
max_val = 1

data = np.linspace(min_val, max_val, 100)

pdf = dunif(data, min_val, max_val)
cdf = punif(data, min_val, max_val)
ppf = qunif(data, min_val, max_val)

fig, axis = plt.subplots(3, 1, figsize=(5,7))

axis[0].plot(data, pdf, "r-")
axis[1].plot(data, cdf, "b-")
axis[2].plot(data, ppf, "g-")

plt.tight_layout()
plt.show()

# %% [markdown]
# aqui se representan gráficamente las funciones de densidad, acumulada y cuantil
